# %%
import random
import string

def generate_password(length):
    characters = string.ascii_letters + string.digits + string.punctuation
    password = ''.join(random.choice(characters) for i in range(length))
    return password

# Generate and print passwords from 1 to 40 characters
for length in range(1, 41):
    print(f"Password of length {length}: {generate_password(length)}")
# Out:
# Password of length 1: v
# Password of length 2: |@
# Password of length 3: g-k
# Password of length 4: iE{~
# Password of length 5: :,#fG
# Password of length 6: :*<^4E
# Password of length 7: %!ro(&L
# Password of length 8: 0;H$Ocot
# Password of length 9: 453=Xm?uy
# Password of length 10: &oZ{Khj~s)
# Password of length 11: btj>z?{?xov
# Password of length 12: YOj:Wg6-:F1W
# Password of length 13: B6RZzca@\$spx
# Password of length 14: 8}0AVF/c@QlB5B
# Password of length 15: ]l~[a\"*6UiLai-
# Password of length 16: )s&hU{KgpDQ%ZzFc
# Password of length 17: ~F)$j!ez`A;jS)<W3
# Password of length 18: qU'A(Bn-_#gP[pf34P
# Password of length 19: OmO/S}e_O^d;GO4K~aU
# Password of length 20: V:h"7zj#lp$VYe{)~vsG
# Password of length 21: 6"Si0"A.8^HW1Q247bKT(
# Password of length 22: -;H{r<7lsNi;*{zK=t;VF/
# Password of length 23: *h_\edWfoB`@{iKv{^5O3W&
# Password of length 24: AP}JX:P\WthGatf*f]`X_|dU
# Password of length 25: z{7m%cQc)ZQ.2%6wy"sQ]K|F8
# Password of length 26: *ksdxZO/lM$3V(ed)?;c9d>DQG
# Password of length 27: GA=J"5m$D9Y9:sG$Cl?2(5n3}{,
# Password of length 28: BOb<GA57Y<&S%GyHR2'Y27p@#+rV
# Password of length 29: =<9B@N[)O74Ya0P^~d`A^a%W3^d;{
# Password of length 30: e/i&rg:{[2niEZ(QI1iXn/=B'm@,y$
# Password of length 31: FF)6N%JXqbV3I/;&;9rH;H9t>dME^8:
# Password of length 32: x'=38jebozQx9tdm}G>uW]"*rfyxhc8.
# Password of length 33: `*:t{?OS}Lr|aWGo0O[n3dg7NO#HB4ZQD
# Password of length 34: 3D-.^j74o@}Z|>6G-mYhpDNa3U5_q9P[5g
# Password of length 35: rUpJxde%esr(4|cM7.BVE:*#Z',T"DZ;(J@
# Password of length 36: bG6O@s#:Ee_e;4d7*s]6HYYodPK<^7@<@9%4
# Password of length 37: Y=g4n-~2<LdU_0PL%Rx}xgl5Up*-"~%S'apVW
# Password of length 38: OufZI'o|d_mH_gDQXiV@#jlfG|n'Gx8eZ&"z)E
# Password of length 39: D]AMqZQ,Z,6w&?}.\?9\uoJIr^f6378KCfe~m#T
# Password of length 40: |1{WxR?r]TMjrT+!_Z4MV8Le?>OuqtO^0(.ryn3:

# %%
import random
import string

def generate_password(length):
    characters = string.ascii_letters + string.digits + string.punctuation
    password = ''.join(random.choice(characters) for i in range(length))
    return password

# Generate and print passwords from 1 to 60 characters
for length in range(1, 61):
    print(f"Password of length {length}: {generate_password(length)}")
# Out:
# Password of length 1: i
# Password of length 2: qz
# Password of length 3: h'6
# Password of length 4: ^5&^
# Password of length 5: d.IQp
# Password of length 6: eM!Y)H
# Password of length 7: F(&zV~/
# Password of length 8: JA2`F@NF
# Password of length 9: TXVzdzz8n
# Password of length 10: /0v|Q.^3[7
# Password of length 11: #w?4"&2!k~6
# Password of length 12: o;c1d3:_:qx`
# Password of length 13: 4}k/5;:6xO76e
# Password of length 14: <`]VhtBa1ip58I
# Password of length 15: ic*l)C5rN!JKAnf
# Password of length 16: Xn7X^.'f^/\r*Z0'
# Password of length 17: 3jSH.C3;C:R`|6_ZR
# Password of length 18: nG[O<NCkhl&Bd/D_HX
# Password of length 19: "G*:pZ@m/,6UMa2BCxi
# Password of length 20: ]ElW4\ZiGSR.99Gz"2xX
# Password of length 21: u@)qQ6m15gQ*guU?Xm'aN
# Password of length 22: c[I-%eg'$~?NylK#j}Zu?T
# Password of length 23: &iq}=v,JKz0H{.YiW+%c`Af
# Password of length 24: +7FBt|VW5~sCHnlg=wd,n0vi
# Password of length 25: M6o&4O"5l]"zYvtb9xk*>biXb
# Password of length 26: S~,!/I[<PvoLPQ.(A)YMY9kG}L
# Password of length 27: =6N~p{Yhz9hTfplC/I<wKHutmlN
# Password of length 28: b`VC$~_'^DRWwb&6>sott37Ew3CI
# Password of length 29: a7vnnNfD`TVZQ(2-EM/^bwnde8$/;
# Password of length 30: Co:GHd.1\T,ZlkY/`/PD\p*%zmX:1f
# Password of length 31: *%9[2haA_6b\@JbWw/zNxv#}P-h4E;j
# Password of length 32: |9z>pt,>zq@E8LDK$Idk2G[nmQA>%_m$
# Password of length 33: :3Y$d<_D~-Rk0]\;EaX,T.u^%g<vzXF[X
# Password of length 34: 9{dn-,OF(p^,T]Nc*AO/z?e^iH]eT|A1CP
# Password of length 35: d0(KXLo\[v!hSv%G!1-cekQ]%ZHZF),\''h
# Password of length 36: 1VJEA)X;/L,Z~ue8++psQo7*CUk}j-Y@"C[\
# Password of length 37: u8iexne8_KL=Ogfo,m>=UoV3L[6<gKW-sMkP-
# Password of length 38: $lSmnDb{zN1f|jJ='Bzl*o+?Bvskic"p:4s6jE
# Password of length 39: g]^BU_fBbxtjp\3}MC4;5?<Sa[9761F5=>:{GXr
# Password of length 40: OWc|b26q`*?y@x87p2Mn7?!-|\WD.90pV^[mE[Je
# Password of length 41: "`>j#%7)a!k:7|Pt_!${ZJP9GN:n'JRB=sZngs=7_
# Password of length 42: RG31u:K&X"Ge60#~apAdoBf+#U_W!v^Ka[j?G#|E7&
# Password of length 43: PM]4`Sh@U`Cy,zr,{9B<BEU!<fiN"XeQU}wgs+"6UGp
# Password of length 44: "CU3,5(h=128NW5U[Nl,@ZPuCb`M,fj.\5Mv@})C!ACg
# Password of length 45: Eeir\h5_QfhSqNnvt[F\ob:/.k_cGRr'zk{e<\jG;1sI*
# Password of length 46: YS6ipRSZ#-SwuKK0+N|RkN!A28e|/u,sp#K"go{s\-=<>g
# Password of length 47: &p.&Z65+I0PLHo}FhR:OJ=9`m+$WdXepGSrH>T3xpDPZ6J%
# Password of length 48: T"*ZlOLB8A{6Q4f2.bAW80:?-cPG"9tKxYqQ)4,_Zg.<=gF3
# Password of length 49: _s3.f$r+*,<zSX6[C.B'{{Y=!`-=~9M9UHXM)4\`~5iOC8eSG
# Password of length 50: ,eA?ayU;k9~>rtsL1p75$SaBM+a\@l}dEt9z'TE;KHw-l);w23
# Password of length 51: UKmY"6@%@/T/\+TH8J^-)gW,yqBY>l_C$&`6Oj6D`t!E:R>;ka~
# Password of length 52: qwB2KwR/:TeSIuO}8h!,eKJ6+1?GV$o0"75#twD]#(mznw5%Dlm]
# Password of length 53: ?Sipk.hN~vr7zJ*<rf]SWiZ^\xwUo~Moi'$5rw(a<?<`R:bH^pL}p
# Password of length 54: 0V2xc7<"A:Oic:?\xO8}00A_/:Q|y#,LJLuo?P]&v:0Cw!`|4h6q74
# Password of length 55: Q1{YTAzw1;iRtg@w>)K=0rBz2;+0Vp'#tF)h.MX`{u<e35-NzT)J~@p
# Password of length 56: yk5~NZ~n`B4sKQgbVXS.G[)@0pl96Xo*}pJqP,T3&$NzW3m`]DX0?T)K
# Password of length 57: >zPqLqxYdD;wCw^h'o8<qO9oD^TwOdLNkr$krUZB';IIiQbS>dII`802g
# Password of length 58: 7d?Z/AX=G^R2=hpKJhvot"WNz}+U9wlxAr>q\yb>6+v.88NkhO*B>4sBn*
# Password of length 59: @cGNv!6GU)*)+-j"j9&rc[EjYt&rzZc/8d}tY9#a=jF'YAz$:LwAM>-)]ou
# Password of length 60: y5%PTx2=MqJ*+Ma4>Q^\JZ|{JLibY-!<\TmjVvBISL,^GSY^Q*Xek{9|U<`1
